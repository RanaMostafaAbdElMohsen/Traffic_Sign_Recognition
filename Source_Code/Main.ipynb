# %% [markdown]
# # Main Program
# ## Execution of main program and functions call

# %%
def IntialiseEnv():
    nb_dir = os.path.split(os.getcwd())[0]
    if nb_dir not in sys.path:
        sys.path.append(nb_dir)

# %%
# Libraries
import os
import sys
IntialiseEnv()
import tensorflow as tf
import numpy as np
import math
import pickle
import import_ipynb

# %% [markdown]
# ## Loading Test Images

# %%
def ReadBelgiumTestDataSet():
    processedTestDataSet = 'DataSet/Processed_DataSet/BelgiumTestDataSet.pkl'
    isProcessedTestDataSetExits= os.path.exists(processedTestDataSet)
    test_image_array, test_image_labels = None, None
    
    if isProcessedTestDataSetExits:
        print("Loading Processed Test DataSet from Processed_DataSet/BelgiumTestDataSet.pkl")
        file = open(processedTestDataSet, 'rb')
        test_image_array, test_image_labels = pickle.load(file)
        file.close()
        print("Done Loading Test DataSet.")
    return test_image_array, test_image_labels

# %%
def ReadGermanTestDataSet():
    processedTestDataSet = 'DataSet/Processed_DataSet/GermanTestDataSet.pkl'
    isProcessedTestDataSetExits= os.path.exists(processedTestDataSet)
    test_image_array, test_image_labels = None, None
    
    if isProcessedTestDataSetExits:
        print("Loading Processed Test DataSet from Processed_DataSet/GermanTestDataSet.pkl")
        file = open(processedTestDataSet, 'rb')
        test_image_array, test_image_labels = pickle.load(file)
        file.close()
        print("Done Loading Test DataSet.")
        
    return test_image_array, test_image_labels

# %%
test_image_belgium_array, test_image_belgium_labels = ReadBelgiumTestDataSet()
# Out:
# Loading Processed Test DataSet from Processed_DataSet/BelgiumTestDataSet.pkl
# Done Loading Test DataSet.

# %%
test_image_german_aray, test_image_german_labels = ReadGermanTestDataSet()
# Out:
# Loading Processed Test DataSet from Processed_DataSet/GermanTestDataSet.pkl
# Done Loading Test DataSet.

# %% [markdown]
# ## Models Evaluation

# %%
def load_model(model_name):
    Model = tf.keras.models.load_model('Model/Trained_Models/'+ model_name)
    return Model

# %%
def AccuracyEvaluation(model_name, test_image_array, test_image_labels):
    model= load_model(model_name)
    _, acc = model.evaluate(test_image_array, np.array(test_image_labels), batch_size=128)
    del model
    return acc

# %%
print("Running German Traffic Sign Model ")
accuracy= AccuracyEvaluation('German_Winning_99_69.h5', test_image_german_aray, test_image_german_labels)
print("Accuracy is: ", accuracy*100)
# Out:
# Running German Traffic Sign Model
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# ...

# %%
print("Running Belgium Traffic Sign Model ")
accuracy= AccuracyEvaluation('Belgium_Winning_98_97.h5', test_image_belgium_array, test_image_belgium_labels)
print("Accuracy is: ", accuracy*100)
# Out:
# Running Belgium Traffic Sign Model
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# ...
